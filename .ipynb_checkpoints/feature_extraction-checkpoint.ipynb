# %%
import os, re
import numpy as np
import pickle as pkl
from matplotlib import cm
import matplotlib.pyplot as plt
import scipy.io.wavfile as wav
import speechpy
import shutil

# %%
def decode(path_from, path_to, file_name, separator):
    if not os.path.exists(path_to):
        os.makedirs(path_to)
    from pydub import AudioSegment
    try:
        sound = AudioSegment.from_mp3(os.path.abspath(path_from + file_name))
        sound.export(os.path.abspath(path_to)+separator+re.split('[.]', file_name)[0]+'.wav', format="wav")
        print('Successfully decoding ' + os.path.abspath(path_to+file_name) + ' to WAV')
    except Exception as e:
        file = os.path.abspath(path_to+file_name)
        print(f'Error: {file} - unsuccessfully decoding. ', e)

# %%
def extr_mfcc(path_from, file_name):
    try:
        fs, signal = wav.read(path_from, file_name)
        signal = signal[:,0]
    except Exception as e:
        print(f'Error: reading wav file {file_name}.', e)
    try:
        mfcc = speechpy.feature.mfcc(signal, sampling_frequency=fs, frame_length=0.020, frame_stride=0.01,
                 num_filters=40, fft_length=512, low_frequency=0, high_frequency=None)
        mfcc_cmvn = speechpy.processing.cmvnw(mfcc,win_size=301,variance_normalization=True)
        mfcc_feature_cube = speechpy.feature.extract_derivative_feature(mfcc)
        return (mfcc, mfcc_cmvn, mfcc_feature_cube)
    except Exception as e:
        print("Error: feature extraction from file {file_name}.", e) 
        return (np.asarray([]), np.asarray([]), np.asarray([]))

# %%
def get_playlist(path, expantion):
    for l in [filename for filename in os.listdir(path) if expantion in filename]:
        yield l

# %%
def dump(file_name, path_to, data):
    if not os.path.exists(path_to):
        os.makedirs(path_to)
    pkl_name = re.split(r'\\',file_name)[-1][:-4]
    pkl.dump(features[0], open(path_to + pkl_name, 'wb'))

# %%
def plot_2d_features(features, range_from, range_to, plotname):
    #Showing mfcc_data
    #ig, ax = plt.subplots()
    #mfcc_data= np.swapaxes(features[range_from:range_to], 0 ,1)
    #cax = ax.imshow(mfcc_data, interpolation='nearest', cmap=cm.coolwarm, origin='lower', aspect='auto')
    #ax.set_title(plotname)
    #plt.show()
    
    #Showing mfcc_feat
    plt.figure(figsize = (20, 10))
    plt.plot(features[range_from:range_to])
    plt.show()

# %%
def clear_dir(path):
    shutil.rmtree(os.path.abspath(path))

# %%
for file_name in get_playlist('.\\tracks\\', '.mp3'):
    #декодируем один трек в папку wavs
    decode(path_from = '.\\tracks\\', path_to = '.\\wavs\\', file_name = file_name, separator = '\\')
    for wav_files in get_playlist('.\\wavs\\', '.wav'):
        features = extr_mfcc(wav_files)
        if len(features[0]):
            dump(file_name, ".\\mfccs\\", features[0])
        print(file_name)
        plot_2d_features(features[0], 0,len(features[0]),'MFCC')
        plot_2d_features(features[1], 0,len(features[0]),'MFCC_SMVN')
        clear_dir('.\\wavs\\')
# Out:
# Successfully decoding c:\Users\Kozyrevsky-V\Documents\recom\RecomendationSystem\wavs\Billy Joel, Elton John - Piano Man (live).mp3 to WAV
# Error: reading wav file Billy Joel, Elton John - Piano Man (live).wav. [Errno 2] No such file or directory: 'Billy Joel, Elton John - Piano Man (live).wav'
# Error: feature extraction from file {file_name}. local variable 'signal' referenced before assignment
# Billy Joel, Elton John - Piano Man (live).mp3
# Successfully decoding c:\Users\Kozyrevsky-V\Documents\recom\RecomendationSystem\wavs\DJ Snake - Magenta Riddim.mp3 to WAV
# Error: reading wav file DJ Snake - Magenta Riddim.wav. [Errno 2] No such file or directory: 'DJ Snake - Magenta Riddim.wav'
# Error: feature extraction from file {file_name}. local variable 'signal' referenced before assignment
# DJ Snake - Magenta Riddim.mp3
# Successfully decoding c:\Users\Kozyrevsky-V\Documents\recom\RecomendationSystem\wavs\Elthon John - Sacrifice.mp3 to WAV
# Error: reading wav file Elthon John - Sacrifice.wav. [Errno 2] No such file or directory: 'Elthon John - Sacrifice.wav'
# Error: feature extraction from file {file_name}. local variable 'signal' referenced before assignment
# Elthon John - Sacrifice.mp3
# Successfully decoding c:\Users\Kozyrevsky-V\Documents\recom\RecomendationSystem\wavs\Elton John - Bennie and the Jets (with lyrics).mp3 to WAV
# Error: reading wav file Elton John - Bennie and the Jets (with lyrics).wav. [Errno 2] No such file or directory: 'Elton John - Bennie and the Jets (with lyrics).wav'
# Error: feature extraction from file {file_name}. local variable 'signal' referenced before assignment
# Elton John - Bennie and the Jets (with lyrics).mp3
# Successfully decoding c:\Users\Kozyrevsky-V\Documents\recom\RecomendationSystem\wavs\Elton John - Can You Feel the Love Tonight (live).mp3 to WAV
# Error: reading wav file Elton John - Can You Feel the Love Tonight (live).wav. [Errno 2] No such file or directory: 'Elton John - Can You Feel the Love Tonight (live).wav'
# Error: feature extraction from file {file_name}. local variable 'signal' referenced before assignment
# Elton John - Can You Feel the Love Tonight (live).mp3
# Successfully decoding c:\Users\Kozyrevsky-V\Documents\recom\RecomendationSystem\wavs\Elton John - Can you feel the love tonight.mp3 to WAV
# Error: reading wav file Elton John - Can you feel the love tonight.wav. [Errno 2] No such file or directory: 'Elton John - Can you feel the love tonight.wav'
# Error: feature extraction from file {file_name}. local variable 'signal' referenced before assignment
# Elton John - Can you feel the love tonight.mp3
# Successfully decoding c:\Users\Kozyrevsky-V\Documents\recom\RecomendationSystem\wavs\Elton John - Candle In The Wind.mp3 to WAV
# Error: reading wav file Elton John - Candle In The Wind.wav. [Errno 2] No such file or directory: 'Elton John - Candle In The Wind.wav'
# Error: feature extraction from file {file_name}. local variable 'signal' referenced before assignment
# Elton John - Candle In The Wind.mp3
# Successfully decoding c:\Users\Kozyrevsky-V\Documents\recom\RecomendationSystem\wavs\Elton John - I Guess That's Why They Call It The Blues.mp3 to WAV
# Error: reading wav file Elton John - I Guess That's Why They Call It The Blues.wav. [Errno 2] No such file or directory: "Elton John - I Guess That's Why They Call It The Blues.wav"
# Error: feature extraction from file {file_name}. local variable 'signal' referenced before assignment
# Elton John - I Guess That's Why They Call It The Blues.mp3
# Successfully decoding c:\Users\Kozyrevsky-V\Documents\recom\RecomendationSystem\wavs\Elton John - I'm Still Standing.mp3 to WAV
# Error: reading wav file Elton John - I'm Still Standing.wav. [Errno 2] No such file or directory: "Elton John - I'm Still Standing.wav"
# Error: feature extraction from file {file_name}. local variable 'signal' referenced before assignment
# Elton John - I'm Still Standing.mp3
# Successfully decoding c:\Users\Kozyrevsky-V\Documents\recom\RecomendationSystem\wavs\Elton John - Rocket Man (Official Music Video).mp3 to WAV
# Error: reading wav file Elton John - Rocket Man (Official Music Video).wav. [Errno 2] No such file or directory: 'Elton John - Rocket Man (Official Music Video).wav'
# Error: feature extraction from file {file_name}. local variable 'signal' referenced before assignment
# Elton John - Rocket Man (Official Music Video).mp3
# Successfully decoding c:\Users\Kozyrevsky-V\Documents\recom\RecomendationSystem\wavs\Elton John - Spirit In The Sky.mp3 to WAV
# Error: reading wav file Elton John - Spirit In The Sky.wav. [Errno 2] No such file or directory: 'Elton John - Spirit In The Sky.wav'
# Error: feature extraction from file {file_name}. local variable 'signal' referenced before assignment
# Elton John - Spirit In The Sky.mp3
# Successfully decoding c:\Users\Kozyrevsky-V\Documents\recom\RecomendationSystem\wavs\Elton John - Tiny Dancer (Official Music Video).mp3 to WAV
# Error: reading wav file Elton John - Tiny Dancer (Official Music Video).wav. [Errno 2] No such file or directory: 'Elton John - Tiny Dancer (Official Music Video).wav'
# Error: feature extraction from file {file_name}. local variable 'signal' referenced before assignment
# Elton John - Tiny Dancer (Official Music Video).mp3
# Successfully decoding c:\Users\Kozyrevsky-V\Documents\recom\RecomendationSystem\wavs\Elton John - Tiny Dancer.mp3 to WAV
# Error: reading wav file Elton John - Tiny Dancer.wav. [Errno 2] No such file or directory: 'Elton John - Tiny Dancer.wav'
# Error: feature extraction from file {file_name}. local variable 'signal' referenced before assignment
# Elton John - Tiny Dancer.mp3
